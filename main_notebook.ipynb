# %% [markdown]
# <img style="float: left; width: 150px; margin-right: 20px;" src="fourtuna_wheel.png">
# # Fortuna
# ### Main Notebook
# In this Notebook we can test all methods of Fortuna, before actually calling them in the webfrontend :)

# %%
# Load  Fortuna
import fortuna.fortuna as ft
import numpy as np

# %%
# Initialize an object of fortuna and create xarray
f_data = ft.Fortuna()

# %%
# Calculate lithology block iterations with the new vectorized method
lith = f_data.calc_lithology_vect(iterations=200)

# %%
# Compare to the old lithology method
#lith_old = f_data.calc_lithology(iterations=5)

# %%
# Calculate lithology probability block from lithology blocks
prob = f_data.calc_probability_lithology(lith)

# %%
# Calculate entropy block
entro = f_data.calc_information_entropy(prob)

# %%
f_data.plot_entropy(entro[::-1,::-1], 60)

# %%
# Export data into pickle
import time
np.save('pickles/entropy_' + time.strftime("%Y%m%d"), entro)

# %%
import sys
print(sys.version)
# Out:
# 3.6.3 |Anaconda, Inc.| (default, Nov 20 2017, 20:41:42)
# [GCC 7.2.0]

# %% [markdown]
# ### View entropy block from hackathon presentation to compare

# %%
entropy = f_object.load_pickle('pickles/entropy_final_presentation.npy')
f_object.plot_entropy(entropy[::-1,::-1], 60)

# %%
np.max(entropy)
# Out:
# 1.582683189255492
